# %%
import pandas as pd

# Load the dataframe.
df = pd.read_csv("influencer_marketing_roi_dataset.csv")

# Print some info.
print(df.head())
print(df.info())
# Out:
#   campaign_id   platform influencer_category    campaign_type  \
# 0  CAMP100000     TikTok             Fitness         Giveaway
# 1  CAMP100001    YouTube                Food   Product Launch
# 2  CAMP100002     TikTok              Travel  Brand Awareness
# 3  CAMP100003    YouTube                Food  Brand Awareness
# 4  CAMP100004  Instagram                Food         Giveaway
#
#             start_date  engagements  estimated_reach  product_sales  \
# 0  2022-01-01 00:00:00        79900             1892           2834
# 1  2022-01-02 00:00:00        47985           437228            165
# 2  2022-01-03 00:00:00        13875           982513           2539
# 3  2022-01-04 00:00:00        41200           213400            100
# 4  2022-01-05 00:00:00        96998            42501            550
#
#    campaign_duration_days             end_date
# 0                      14  2022-01-15 00:00:00
# 1                      13  2022-01-15 00:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataframe.
df = pd.read_csv("influencer_marketing_roi_dataset.csv")

# Group by platform and calculate the average of key metrics.
platform_metrics = df.groupby('platform')[['engagements', 'estimated_reach', 'product_sales']].mean().reset_index()

print("Platformlara göre ortalama kampanya metrikleri:")
print(platform_metrics)

# Create a bar chart for average product sales by platform.
plt.figure(figsize=(10, 6))
sns.barplot(x='platform', y='product_sales', data=platform_metrics.sort_values(by='product_sales', ascending=False), palette='viridis')
plt.title('Platformlara Göre Ortalama Ürün Satışı')
plt.xlabel('Platform')
plt.ylabel('Ortalama Ürün Satışı')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('avg_product_sales_by_platform.png')

# Create a bar chart for average engagements by platform.
plt.figure(figsize=(10, 6))
sns.barplot(x='platform', y='engagements', data=platform_metrics.sort_values(by='engagements', ascending=False), palette='magma')
plt.title('Platformlara Göre Ortalama Etkileşim')
plt.xlabel('Platform')
plt.ylabel('Ortalama Etkileşim')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('avg_engagements_by_platform.png')

# Create a bar chart for average estimated reach by platform.
plt.figure(figsize=(10, 6))
sns.barplot(x='platform', y='estimated_reach', data=platform_metrics.sort_values(by='estimated_reach', ascending=False), palette='cividis')
plt.title('Platformlara Göre Ortalama Tahmini Erişim')
plt.xlabel('Platform')
plt.ylabel('Ortalama Tahmini Erişim')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('avg_reach_by_platform.png')
# Out:
# Platformlara göre ortalama kampanya metrikleri:
#     platform   engagements  estimated_reach  product_sales
# 0  Instagram  50119.526054    500290.766830    2495.212274
# 1     TikTok  49824.596752    500945.575540    2493.339281
# 2    Twitter  50364.985988    499498.964338    2499.107650
# 3    YouTube  50053.342320    499950.028025    2503.524978

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataframe.
df = pd.read_csv("influencer_marketing_roi_dataset.csv")

# Group by campaign type and calculate the average of key metrics.
campaign_type_metrics = df.groupby('campaign_type')[['engagements', 'estimated_reach', 'product_sales']].mean().reset_index()

print("Kampanya Türlerine göre ortalama kampanya metrikleri:")
print(campaign_type_metrics)

# Create a bar chart for average product sales by campaign type.
plt.figure(figsize=(12, 7))
sns.barplot(x='campaign_type', y='product_sales', data=campaign_type_metrics.sort_values(by='product_sales', ascending=False), palette='viridis')
plt.title('Kampanya Türlerine Göre Ortalama Ürün Satışı')
plt.xlabel('Kampanya Türü')
plt.ylabel('Ortalama Ürün Satışı')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('avg_product_sales_by_campaign_type.png')

# Create a bar chart for average engagements by campaign type.
plt.figure(figsize=(12, 7))
sns.barplot(x='campaign_type', y='engagements', data=campaign_type_metrics.sort_values(by='engagements', ascending=False), palette='magma')
plt.title('Kampanya Türlerine Göre Ortalama Etkileşim')
plt.xlabel('Kampanya Türü')
plt.ylabel('Ortalama Etkileşim')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('avg_engagements_by_campaign_type.png')

# Create a bar chart for average estimated reach by campaign type.
plt.figure(figsize=(12, 7))
sns.barplot(x='campaign_type', y='estimated_reach', data=campaign_type_metrics.sort_values(by='estimated_reach', ascending=False), palette='cividis')
plt.title('Kampanya Türlerine Göre Ortalama Tahmini Erişim')
plt.xlabel('Kampanya Türü')
plt.ylabel('Ortalama Tahmini Erişim')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('avg_reach_by_campaign_type.png')
# Out:
# Kampanya Türlerine göre ortalama kampanya metrikleri:
#      campaign_type   engagements  estimated_reach  product_sales
# 0  Brand Awareness  50021.178787    499000.129506    2502.158381
# 1  Event Promotion  49853.344116    499005.740321    2495.961519
# 2         Giveaway  50556.217281    499827.426082    2498.167501
# 3   Product Launch  49730.337865    503157.796061    2492.984505
# 4    Seasonal Sale  50164.385206    500198.601191    2499.362171
# C:\Users\Mutlu\AppData\Local\Temp\ipykernel_20692\2167954740.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='campaign_type', y='product_sales', data=campaign_type_metrics.sort_values(by='product_sales', ascending=False), palette='viridis')
# C:\Users\Mutlu\AppData\Local\Temp\ipykernel_20692\2167954740.py:26: FutureWarning:
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataframe.
df = pd.read_csv("influencer_marketing_roi_dataset.csv")

# Group by influencer category and calculate the average of key metrics.
influencer_category_metrics = df.groupby('influencer_category')[['engagements', 'estimated_reach', 'product_sales']].mean().reset_index()

print("Influencer Kategorilerine göre ortalama kampanya metrikleri:")
print(influencer_category_metrics)

# Create a bar chart for average product sales by influencer category.
plt.figure(figsize=(12, 7))
sns.barplot(x='influencer_category', y='product_sales', data=influencer_category_metrics.sort_values(by='product_sales', ascending=False), palette='viridis')
plt.title('Influencer Kategorilerine Göre Ortalama Ürün Satışı')
plt.xlabel('Influencer Kategorisi')
plt.ylabel('Ortalama Ürün Satışı')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('avg_product_sales_by_influencer_category.png')

# Create a bar chart for average engagements by influencer category.
plt.figure(figsize=(12, 7))
sns.barplot(x='influencer_category', y='engagements', data=influencer_category_metrics.sort_values(by='engagements', ascending=False), palette='magma')
plt.title('Influencer Kategorilerine Göre Ortalama Etkileşim')
plt.xlabel('Influencer Kategorisi')
plt.ylabel('Ortalama Etkileşim')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('avg_engagements_by_influencer_category.png')

# Create a bar chart for average estimated reach by influencer category.
plt.figure(figsize=(12, 7))
sns.barplot(x='influencer_category', y='estimated_reach', data=influencer_category_metrics.sort_values(by='estimated_reach', ascending=False), palette='cividis')
plt.title('Influencer Kategorilerine Göre Ortalama Tahmini Erişim')
plt.xlabel('Influencer Kategorisi')
plt.ylabel('Ortalama Tahmini Erişim')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('avg_reach_by_influencer_category.png')
# Out:
# Influencer Kategorilerine göre ortalama kampanya metrikleri:
#   influencer_category   engagements  estimated_reach  product_sales
# 0              Beauty  50313.225633    500540.901406    2492.125539
# 1             Fashion  50147.215189    499881.760255    2487.668217
# 2             Fitness  49770.338598    502930.754561    2502.891943
# 3                Food  50249.086754    499502.314419    2506.134540
# 4              Gaming  49950.966961    499467.520772    2483.440021
# 5                Tech  50109.207519    501167.018844    2503.362961
# 6              Travel  49911.802849    498210.786732    2508.455163
# C:\Users\Mutlu\AppData\Local\Temp\ipykernel_20692\2235148710.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# Analiz Bulguları
# 1. Platforma Göre Etkinlik Analizi
# Farklı platformların ortalama kampanya metrikleri oldukça benzer bir dağılım göstermektedir. Bu durum, kampanya başarısında platformun tek başına belirleyici bir faktör olmadığını, diğer değişkenlerin de önemli rol oynadığını düşündürmektedir.
#
# Ortalama Ürün Satışı: En yüksek ortalama ürün satışı YouTube'da görülürken, diğer platformlar da benzer satış rakamlarına sahiptir.
#
# Ortalama Etkileşim: Twitter en yüksek ortalama etkileşim sayısına ulaşırken, Instagram ve YouTube onu takip etmektedir.
#
# Ortalama Tahmini Erişim: TikTok en yüksek ortalama tahmini erişime sahiptir.
#
# 2. Kampanya Türüne Göre Etkinlik Analizi
# Kampanya türleri arasında da metrikler açısından büyük farklılıklar gözlemlenmemiştir. Ancak bazı ufak tefek farklılıklar bulunmaktadır.
#
# Ortalama Ürün Satışı: Brand Awareness kampanyaları en yüksek ortalama ürün satışını elde etmiştir.
#
# Ortalama Etkileşim: Giveaway kampanyaları en yüksek etkileşimi sağlamıştır. Bu, bu tür kampanyaların doğası gereği beklenen bir sonuçtur.
#
# Ortalama Tahmini Erişim: Product Launch kampanyaları en yüksek tahmini erişime ulaşmıştır.
#
# 3. Influencer Kategorisine Göre Etkinlik Analizi
# Influencer kategorileri de genel olarak benzer metrikler göstermektedir, ancak bazı öne çıkan noktalar bulunmaktadır.
#
# Ortalama Ürün Satışı: Travel ve Food kategorisindeki influencerlar, en yüksek ortalama ürün satışına ulaşmıştır.
#
# Ortalama Etkileşim: Beauty ve Food kategorileri en yüksek ortalama etkileşimi sağlamıştır.
#
# Ortalama Tahmini Erişim: Fitness ve Tech kategorileri en yüksek tahmini erişime sahiptir.
#
# Sonuç ve Öneriler
# Bu analizler, kampanyaların başarısında tek bir faktörün baskın olmadığını, kampanya stratejisinin bir bütün olarak değerlendirilmesi gerektiğini göstermektedir.
#
# En çok satış getiren kampanyalar için Brand Awareness ve Travel/Food kategorisindeki influencerlar tercih edilebilir.
#
# Etkileşimi artırmak için Giveaway türü kampanyalara odaklanılabilir.
#
# Erişimi maksimize etmek için Product Launch kampanyaları ve Fitness/Tech influencerları kullanılabilir.

# %% [markdown]
# Özet
# Bu proje, influencer pazarlama kampanyalarının platform, kampanya türü ve influencer kategorisi bazında performansını incelemiştir. Veri eksikliği nedeniyle doğrudan ROI hesaplaması yapılamamış olsa da, analizler en çok satış ve etkileşimi getiren stratejiler hakkında içgörüler sunmaktadır.
